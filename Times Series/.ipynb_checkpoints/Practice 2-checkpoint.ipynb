# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import statsmodels.tsa.stattools as sts
from statsmodels.tsa.arima_model import ARMA
from scipy.stats.distributions import chi2
import statsmodels.graphics.tsaplots as sgt
from math import sqrt
import seaborn as sns
sns.set()

# %%
raw_data = pd.read_csv('GOOG1.csv')

# %%
raw_data.isnull().sum()
# Out:
# Date         0
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64

# %%
raw_data.count()
# Out:
# Date         2698
# Open         2698
# High         2698
# Low          2698
# Close        2698
# Adj Close    2698
# Volume       2698
# dtype: int64

# %%
data = raw_data.copy()

# %%
raw_data.describe(include='all')
# Out:
#               Date         Open         High          Low        Close  \
# count         2698  2698.000000  2698.000000  2698.000000  2698.000000
# unique        2698          NaN          NaN          NaN          NaN
# top     2017-06-12          NaN          NaN          NaN          NaN
# freq             1          NaN          NaN          NaN          NaN
# mean           NaN   753.438977   760.538327   746.482524   753.766168
# std            NaN   413.703739   418.784358   409.607559   414.434458
# min            NaN   218.336624   220.314209   216.005356   217.220810
# 25%            NaN   384.512497   388.749131   381.415359   386.071670
# 50%            NaN   661.035004   665.910004   653.825012   661.320007
# 75%            NaN  1079.369965  1092.247467  1066.809967  1079.662445
# max            NaN  2119.270020  2152.679932  2104.360107  2128.310059
#
#           Adj Close        Volume
# count   2698.000000  2.698000e+03
# unique          NaN           NaN
# top             NaN           NaN
# freq            NaN           NaN
# mean     753.766168  2.984240e+06
# std      414.434458  2.464619e+06
# min      217.220810  7.922000e+03
# 25%      386.071670  1.393150e+06
# 50%      661.320007  2.051460e+06
# 75%     1079.662445  4.030049e+06
# max     2128.310059  2.976073e+07

# %%
del data['Open']
del data['High']
del data['Low']
del data['Adj Close']
del data['Volume']
data.head()
# Out:
#          Date       Close
# 0  2010-06-07  241.853470
# 1  2010-06-08  241.484848
# 2  2010-06-09  236.124939
# 3  2010-06-10  242.595688
# 4  2010-06-11  243.337906

# %%
data.set_index('Date', inplace=True)

# %%
data.head()
# Out:
#                  Close
# Date
# 2010-06-07  241.853470
# 2010-06-08  241.484848
# 2010-06-09  236.124939
# 2010-06-10  242.595688
# 2010-06-11  243.337906

# %%
data.Close.plot(figsize=(25,5))
plt.title('Daily Closing Price')
plt.show()

# %%
import scipy.stats
import pylab
scipy.stats.probplot(data['Close'], plot=pylab)
pylab.show()

# %%
data.isnull().sum()
# Out:
# Close    0
# dtype: int64

# %%
#Splitting Data into train and test
size = int(len(data)*0.8)
df, df_test = data[:size], data[size:]

# %%
df.count()
# Out:
# Close    2158
# dtype: int64

# %%
df_test.count()
# Out:
# Close    540
# dtype: int64

# %%
sts.adfuller(data.Close)
# Out:
# (1.9480750584933648,
#  0.9986015587537376,
#  26,
#  2671,
#  {'1%': -3.4328006161256743,
#   '5%': -2.862622699657979,
#   '10%': -2.567346357793352},
#  21939.93331238452)

# %%
sts.adfuller(df.Close)
# Out:
# (-0.33375920048535507,
#  0.920585063081451,
#  24,
#  2133,
#  {'1%': -3.433419473570619,
#   '5%': -2.862895974588963,
#   '10%': -2.5674918550982277},
#  15743.138481920385)

# %%
#Filtering Warnings
import warnings
warnings.filterwarnings('ignore')

# %%
sgt.plot_acf(df.Close, zero=False, lags=40)
plt.title('ACF for Price', Size=24)
plt.show()

# %%
sgt.plot_acf(data.Close, zero=False, lags=40)
plt.title('ACF for Price', Size=24)
plt.show()

# %%
sgt.plot_pacf(data.Close, zero=False, lags=40)
plt.title('PACF for Price', Size=24)
plt.show()

# %%
sgt.plot_pacf(df.Close, zero=False, lags=40)
plt.title('PACF for Price', Size=24)
plt.show()

# %%
#Model
#ARMA(1,1)
model_ar_1_ma_1 = ARMA(df.Close, order=(1,1))
results_ar_1_ma_1 = model_ar_1_ma_1.fit()
print(results_ar_1_ma_1.summary())
# Out:
#                               ARMA Model Results
# ==============================================================================
# Dep. Variable:                  Close   No. Observations:                 2158
# Model:                     ARMA(1, 1)   Log Likelihood               -7980.223
# Method:                       css-mle   S.D. of innovations              9.751
# Date:                Thu, 25 Mar 2021   AIC                          15968.447
# Time:                        11:29:14   BIC                          15991.154
# Sample:                             0   HQIC                         15976.752
#
# ===============================================================================
#                   coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------
# const         626.7811    289.455      2.165      0.030      59.459    1194.103
# ar.L1.Close     0.9996      0.000   2148.651      0.000       0.999       1.000
# ma.L1.Close     0.0268      0.023      1.190      0.234      -0.017       0.071
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1            1.0004           +0.0000j            1.0004            0.0000
# MA.1          -37.3293           +0.0000j           37.3293            0.5000
# -----------------------------------------------------------------------------

# %%
df['results_ar_1_ma_1'] = results_ar_1_ma_1.resid

# %%
sts.adfuller(df.results_ar_1_ma_1)
# Out:
# (-10.312572745053432,
#  3.157266998878105e-18,
#  23,
#  2134,
#  {'1%': -3.433418033468612,
#   '5%': -2.862895338734693,
#   '10%': -2.567491516545175},
#  15741.116315251666)

# %%
sgt.plot_pacf(df.results_ar_1_ma_1, zero=False, lags=40)
plt.title('PACF for Price Residuals', Size=24)
plt.show()

# %%
sgt.plot_acf(df.results_ar_1_ma_1, zero=False, lags=40)
plt.title('PACF for Price Residuals', Size=24)
plt.show()

# %%
#Model
#ARMA(8,8)
model_ar_8_ma_8 = ARMA(df.Close, order=(8,8))
results_ar_8_ma_8 = model_ar_8_ma_8.fit()
print(results_ar_8_ma_8.summary())
# Out:
#                               ARMA Model Results
# ==============================================================================
# Dep. Variable:                  Close   No. Observations:                 2158
# Model:                     ARMA(8, 8)   Log Likelihood               -7943.585
# Method:                       css-mle   S.D. of innovations              9.585
# Date:                Thu, 25 Mar 2021   AIC                          15923.170
# Time:                        11:39:26   BIC                          16025.355
# Sample:                             0   HQIC                         15960.546
#
# ===============================================================================
#                   coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------
# const         598.6996    324.625      1.844      0.065     -37.554    1234.953
# ar.L1.Close     0.8977      0.013     66.852      0.000       0.871       0.924
# ar.L2.Close    -0.1236        nan        nan        nan         nan         nan
# ar.L3.Close     0.9291      0.009     98.644      0.000       0.911       0.948
# ar.L4.Close    -0.6355      0.023    -28.038      0.000      -0.680      -0.591
# ar.L5.Close     0.1409      0.010     13.948      0.000       0.121       0.161
# ar.L6.Close    -0.9022      0.006   -142.485      0.000      -0.915      -0.890
# ar.L7.Close     0.6149      0.022     27.764      0.000       0.572       0.658
# ar.L8.Close     0.0784      0.017      4.691      0.000       0.046       0.111
# ma.L1.Close     0.1325      0.025      5.297      0.000       0.083       0.181
# ma.L2.Close     0.1921      0.015     12.535      0.000       0.162       0.222
# ma.L3.Close    -0.6910      0.022    -31.026      0.000      -0.735      -0.647
# ma.L4.Close    -0.1146      0.026     -4.373      0.000      -0.166      -0.063
# ma.L5.Close    -0.2118      0.017    -12.122      0.000      -0.246      -0.178
# ma.L6.Close     0.6351      0.023     27.432      0.000       0.590       0.680
# ma.L7.Close     0.1109      0.025      4.387      0.000       0.061       0.160
# ma.L8.Close    -0.1103      0.021     -5.153      0.000      -0.152      -0.068
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1           -0.7811           -0.6821j            1.0370           -0.3857
# AR.2           -0.7811           +0.6821j            1.0370            0.3857
# AR.3           -0.1080           -1.0162j            1.0219           -0.2669
# AR.4           -0.1080           +1.0162j            1.0219            0.2669
# AR.5            1.0357           -0.4123j            1.1148           -0.0603
# AR.6            1.0357           +0.4123j            1.1148            0.0603
# AR.7            1.0002           -0.0000j            1.0002           -0.0000
# AR.8           -9.1387           -0.0000j            9.1387           -0.5000
# MA.1           -0.7575           -0.6933j            1.0268           -0.3820
# MA.2           -0.7575           +0.6933j            1.0268            0.3820
# MA.3           -0.0950           -1.0061j            1.0106           -0.2650
# MA.4           -0.0950           +1.0061j            1.0106            0.2650
# MA.5           -2.2126           -0.0000j            2.2126           -0.5000
# MA.6            1.1015           -0.4310j            1.1828           -0.0594
# MA.7            1.1015           +0.4310j            1.1828            0.0594
# MA.8            2.7197           -0.0000j            2.7197           -0.0000
# -----------------------------------------------------------------------------

# %%
#Model
#ARMA(8,7)
model_ar_8_ma_7 = ARMA(df.Close, order=(8,7))
results_ar_8_ma_7 = model_ar_8_ma_7.fit()
print(results_ar_8_ma_7.summary())
# Out:
#                               ARMA Model Results
# ==============================================================================
# Dep. Variable:                  Close   No. Observations:                 2158
# Model:                     ARMA(8, 7)   Log Likelihood               -7942.402
# Method:                       css-mle   S.D. of innovations              9.566
# Date:                Thu, 25 Mar 2021   AIC                          15918.805
# Time:                        11:43:32   BIC                          16015.313
# Sample:                             0   HQIC                         15954.104
#
# ===============================================================================
#                   coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------
# const         598.6660        nan        nan        nan         nan         nan
# ar.L1.Close    -0.1427        nan        nan        nan         nan         nan
# ar.L2.Close     0.9947        nan        nan        nan         nan         nan
# ar.L3.Close     1.6650        nan        nan        nan         nan         nan
# ar.L4.Close    -0.2780        nan        nan        nan         nan         nan
# ar.L5.Close    -1.4913        nan        nan        nan         nan         nan
# ar.L6.Close    -0.9694        nan        nan        nan         nan         nan
# ar.L7.Close     0.4998        nan        nan        nan         nan         nan
# ar.L8.Close     0.7218        nan        nan        nan         nan         nan
# ma.L1.Close     1.1883      0.014     82.287      0.000       1.160       1.217
# ma.L2.Close     0.1709      0.014     12.308      0.000       0.144       0.198
# ma.L3.Close    -1.5615      0.013   -116.453      0.000      -1.588      -1.535
# ma.L4.Close    -1.3292      0.022    -59.438      0.000      -1.373      -1.285
# ma.L5.Close     0.2223      0.013     17.604      0.000       0.198       0.247
# ma.L6.Close     1.2207      0.014     88.905      0.000       1.194       1.248
# ma.L7.Close     0.7556      0.014     52.716      0.000       0.728       0.784
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1            1.0000           -0.0000j            1.0000           -0.0000
# AR.2            0.9581           -0.3210j            1.0104           -0.0515
# AR.3            0.9581           +0.3210j            1.0104            0.0515
# AR.4           -0.3932           -0.9232j            1.0034           -0.3141
# AR.5           -0.3932           +0.9232j            1.0034            0.3141
# AR.6           -0.7622           -0.6764j            1.0191           -0.3845
# AR.7           -0.7622           +0.6764j            1.0191            0.3845
# AR.8           -1.2978           -0.0000j            1.2978           -0.5000
# MA.1            0.9645           -0.3129j            1.0140           -0.0499
# MA.2            0.9645           +0.3129j            1.0140            0.0499
# MA.3           -0.4034           -0.9226j            1.0069           -0.3156
# MA.4           -0.4034           +0.9226j            1.0069            0.3156
# MA.5           -0.7484           -0.6805j            1.0115           -0.3825
# MA.6           -0.7484           +0.6805j            1.0115            0.3825
# MA.7           -1.2408           -0.0000j            1.2408           -0.5000
# -----------------------------------------------------------------------------

# %%
#Model
#ARMA(8,6)
model_ar_8_ma_6 = ARMA(df.Close, order=(8,6))
results_ar_8_ma_6 = model_ar_8_ma_6.fit()
print(results_ar_8_ma_6.summary())
# Out:
#                               ARMA Model Results
# ==============================================================================
# Dep. Variable:                  Close   No. Observations:                 2158
# Model:                     ARMA(8, 6)   Log Likelihood               -7943.061
# Method:                       css-mle   S.D. of innovations              9.580
# Date:                Thu, 25 Mar 2021   AIC                          15918.121
# Time:                        11:52:22   BIC                          16008.952
# Sample:                             0   HQIC                         15951.344
#
# ===============================================================================
#                   coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------
# const         598.7068    273.529      2.189      0.029      62.600    1134.814
# ar.L1.Close     0.6411      0.990      0.648      0.517      -1.299       2.581
# ar.L2.Close     0.5058      1.165      0.434      0.664      -1.777       2.789
# ar.L3.Close     1.2661      2.157      0.587      0.557      -2.962       5.494
# ar.L4.Close    -1.2846      0.361     -3.558      0.000      -1.992      -0.577
# ar.L5.Close    -0.5014      1.036     -0.484      0.628      -2.533       1.530
# ar.L6.Close    -0.5623      1.943     -0.289      0.772      -4.370       3.245
# ar.L7.Close     0.9534      0.145      6.557      0.000       0.668       1.238
# ar.L8.Close    -0.0183      0.687     -0.027      0.979      -1.364       1.328
# ma.L1.Close     0.3870      0.991      0.391      0.696      -1.555       2.329
# ma.L2.Close    -0.1413      1.830     -0.077      0.938      -3.728       3.446
# ma.L3.Close    -1.4561      0.211     -6.896      0.000      -1.870      -1.042
# ma.L4.Close    -0.1653      0.130     -1.274      0.203      -0.420       0.089
# ma.L5.Close     0.3567      1.475      0.242      0.809      -2.534       3.247
# ma.L6.Close     0.9427      0.207      4.558      0.000       0.537       1.348
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1           -0.7604           -0.6741j            1.0162           -0.3846
# AR.2           -0.7604           +0.6741j            1.0162            0.3846
# AR.3           -0.3939           -0.9228j            1.0033           -0.3142
# AR.4           -0.3939           +0.9228j            1.0033            0.3142
# AR.5            0.9580           -0.3206j            1.0102           -0.0514
# AR.6            0.9580           +0.3206j            1.0102            0.0514
# AR.7            1.0004           -0.0000j            1.0004           -0.0000
# AR.8           51.3662           -0.0000j           51.3662           -0.0000
# MA.1            0.9638           -0.3121j            1.0131           -0.0498
# MA.2            0.9638           +0.3121j            1.0131            0.0498
# MA.3           -0.4039           -0.9211j            1.0058           -0.3158
# MA.4           -0.4039           +0.9211j            1.0058            0.3158
# MA.5           -0.7491           -0.6786j            1.0108           -0.3829
# MA.6           -0.7491           +0.6786j            1.0108            0.3829
# -----------------------------------------------------------------------------

# %%
#Chosen Models
#Chosing the best Algorithm using LLR and AIC
#ARMA(3,4)
print('\tARMA(8,8): \tLLR = ', results_ar_8_ma_8.llf, '\tAIC = ', results_ar_8_ma_8.aic)
print('\tARMA(8,7): \tLLR = ', results_ar_8_ma_7.llf, '\tAIC = ', results_ar_8_ma_7.aic)
# Out:
# 	ARMA(8,8): 	LLR =  -7943.585198871526 	AIC =  15923.170397743052
# 	ARMA(8,7): 	LLR =  -7942.402442967235 	AIC =  15918.80488593447

# %% [markdown]
# ### Using Return

# %%
df['returns'] = df.Close.pct_change(1) * 100

# %%
df
# Out:
#                   Close  results_ar_1_ma_1   returns
# Date
# 2010-06-07   241.853470        -384.927656       NaN
# 2010-06-08   241.484848          -0.519928 -0.152415
# 2010-06-09   236.124939          -5.505548 -2.219563
# 2010-06-10   242.595688           6.456458  2.740392
# 2010-06-11   243.337906           0.410161  0.305949
# ...                 ...                ...       ...
# 2018-12-24   976.219971          -2.387521 -0.338935
# 2018-12-26  1039.459961          63.448657  6.478047
# 2018-12-27  1043.880005           2.891238  0.425225
# 2018-12-28  1037.079956          -6.704774 -0.651421
# 2018-12-31  1035.609985          -1.120448 -0.141741
#
# [2158 rows x 3 columns]

# %%
df.returns[1:].plot(figsize=(20,5))
plt.title('Returns')
plt.show()

# %%
sts.adfuller(df.returns[1:])
# Out:
# (-45.432369372685365,
#  0.0,
#  0,
#  2156,
#  {'1%': -3.4333866896116727,
#   '5%': -2.8628814992744562,
#   '10%': -2.5674841479015287},
#  7856.4874417668225)

# %%
sgt.plot_acf(df.returns[1:], zero=False, lags=40)
plt.title('ACF For Returns', size=20)
plt.show()

# %%
sgt.plot_pacf(df.returns[1:], zero=False, lags=40)
plt.title('PACF For Returns', size=20)
plt.show()

# %%
#Model
#ARMA(1,1)
model_ret_ar_1_ma_1 = ARMA(df.Close, order=(1,1))
results_ret_ar_1_ma_1 = model_ret_ar_1_ma_1.fit()
print(results_ret_ar_1_ma_1.summary())
# Out:
#                               ARMA Model Results
# ==============================================================================
# Dep. Variable:                  Close   No. Observations:                 2158
# Model:                     ARMA(1, 1)   Log Likelihood               -7980.223
# Method:                       css-mle   S.D. of innovations              9.751
# Date:                Thu, 25 Mar 2021   AIC                          15968.447
# Time:                        12:04:56   BIC                          15991.154
# Sample:                             0   HQIC                         15976.752
#
# ===============================================================================
#                   coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------
# const         626.7811    289.455      2.165      0.030      59.459    1194.103
# ar.L1.Close     0.9996      0.000   2148.651      0.000       0.999       1.000
# ma.L1.Close     0.0268      0.023      1.190      0.234      -0.017       0.071
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1            1.0004           +0.0000j            1.0004            0.0000
# MA.1          -37.3293           +0.0000j           37.3293            0.5000
# -----------------------------------------------------------------------------

# %%
df['results_ret_ar_1_ma_1'] = results_ret_ar_1_ma_1.resid

# %%
df.results_ret_ar_1_ma_1[1:].plot(figsize=(20,5))
plt.title('Residual For Return2 ARMA(1,1)', size=18)
plt.show()

# %%
sts.adfuller(df.results_ret_ar_1_ma_1[1:])
# Out:
# (-10.52015475315087,
#  9.729931546254575e-19,
#  23,
#  2133,
#  {'1%': -3.433419473570619,
#   '5%': -2.862895974588963,
#   '10%': -2.5674918550982277},
#  15734.717594859341)

# %%
sgt.plot_acf(df.results_ret_ar_1_ma_1[1:], zero=False, lags=40)
plt.title('ACF for df.results_ret_ar_1_ma_1', size=18)
plt.show()

# %%
#(5,5)
#Model
#ARMA(5,5)
model_ret_ar_5_ma_5 = ARMA(df.Close, order=(5,5))
results_ret_ar_5_ma_5 = model_ret_ar_5_ma_5.fit()
print(results_ret_ar_5_ma_5.summary())
