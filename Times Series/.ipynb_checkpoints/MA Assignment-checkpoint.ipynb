# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import statsmodels.tsa.stattools as sts
from statsmodels.tsa.arima_model import ARMA
from scipy.stats.distributions import chi2
import statsmodels.graphics.tsaplots as sgt
from math import sqrt
import seaborn as sns
sns.set()

# %%
raw_csv_data = pd.read_csv('013 IndexE81.csv')
df_comp = raw_csv_data.copy()
#Converting Time
df_comp.date = pd.to_datetime(df_comp.date, dayfirst=True)
#Setting Date as an index
df_comp.set_index('date', inplace=True)
#Setting Frequency as business working days
df_comp = df_comp.asfreq('b')
#Filling the Missing or Empty Values
df_comp = df_comp.fillna(method='ffill')
df_comp['market_value'] = df_comp.ftse

# %%
df_comp.head()
# Out:
#                spx      dax     ftse    nikkei  market_value
# date
# 1994-01-07  469.90  2224.95  3445.98  18124.01       3445.98
# 1994-01-10  475.27  2225.00  3440.58  18443.44       3440.58
# 1994-01-11  474.13  2228.10  3413.77  18485.25       3413.77
# 1994-01-12  474.17  2182.06  3372.02  18793.88       3372.02
# 1994-01-13  472.47  2142.37  3360.01  18577.26       3360.01

# %%
df_comp.isnull().sum()
# Out:
# spx             0
# dax             0
# ftse            0
# nikkei          0
# market_value    0
# dtype: int64

# %%
#Deleting unwanted columns
del df_comp['spx']
del df_comp['dax']
del df_comp['ftse']
del df_comp['nikkei']

# %%
#Splitting Data into train and test
size = int(len(df_comp)*0.8)
df, df_test = df_comp[size:], df_comp[:size]

# %%
#Filtering Warnings
import warnings
warnings.filterwarnings('ignore')

# %%
df['returns'] = df.market_value.pct_change(1) * 100

# %%
#ADFULLER TEST
sts.adfuller(df.returns[1:])
# Out:
# (-19.144530699208023,
#  0.0,
#  3,
#  1251,
#  {'1%': -3.4355880246374304,
#   '5%': -2.8638531175675896,
#   '10%': -2.568001531098063},
#  3088.6645857988337)

# %%
#ADFULLER TEST
sts.adfuller(df.market_value)
# Out:
# (-1.6447857147801237,
#  0.45976122733607816,
#  4,
#  1251,
#  {'1%': -3.4355880246374304,
#   '5%': -2.8638531175675896,
#   '10%': -2.568001531098063},
#  13359.94152868575)

# %%
df.returns.plot(figsize=(20,5))
plt.title('Returns', size=24)
plt.show()

# %%
sgt.plot_acf(df.returns[1:], zero=False, lags=40)
plt.title('ACF for Returns', Size=24)
plt.show()

# %%
#Model
model_ret_ma_1 = ARMA(df.returns[1:], order=(0,1))
results_ret_ma_1 = model_ret_ma_1.fit()
print(results_ret_ma_1.summary())
# Out:
#                               ARMA Model Results
# ...
# Dep. Variable:                returns   No. Observations:                 1255
# Model:                     ARMA(0, 1)   Log Likelihood               -1572.688
# Method:                       css-mle   S.D. of innovations              0.847
# Date:                Wed, 17 Mar 2021   AIC                           3151.376
# Time:                        12:51:32   BIC                           3166.781
# Sample:                    04-09-2013   HQIC                          3157.166
#                          - 01-29-2018
# ...
#                     coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const             0.0196      0.025      0.798      0.425      -0.029       0.068
# ma.L1.returns     0.0266      0.029      0.903      0.366      -0.031       0.084
#                                     Roots
# ...

# %%
#LLR Test
def LLR_test(mod_1,mod_2, DF=1):
    #mod_1, mod_2: modelwe want to compare
    #Degree of Freedom
    L1 = mod_1.fit().llf
    L2 = mod_2.fit().llf
    LR = (2*(L2-L1))
    p = chi2.sf(LR,DF).round(2)
    return p

# %%
model_ret_ma_2 = ARMA(df.returns[1:], order=(0,2))
results_ret_ma_2 = model_ret_ma_2.fit()
print(results_ret_ma_2.summary())
print('\n')
print('LLR Test p-value = ' + str(LLR_test(model_ret_ma_1, model_ret_ma_2)))
# Out:
#                               ARMA Model Results
# ...
# Dep. Variable:                returns   No. Observations:                 1255
# Model:                     ARMA(0, 2)   Log Likelihood               -1571.469
# Method:                       css-mle   S.D. of innovations              0.846
# Date:                Wed, 17 Mar 2021   AIC                           3150.938
# Time:                        12:51:40   BIC                           3171.478
# Sample:                    04-09-2013   HQIC                          3158.658
#                          - 01-29-2018
# ...
#                     coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const             0.0195      0.023      0.832      0.405      -0.026       0.065
# ma.L1.returns     0.0296      0.028      1.042      0.297      -0.026       0.085
# ma.L2.returns    -0.0487      0.031     -1.568      0.117      -0.110       0.012
# ...

# %%
model_ret_ma_3 = ARMA(df.returns[1:], order=(0,2))
results_ret_ma_3 = model_ret_ma_3.fit()
print(results_ret_ma_3.summary())
print('\n')
print('LLR Test p-value = ' + str(LLR_test(model_ret_ma_3, model_ret_ma_3)))
# Out:
#                               ARMA Model Results
# ...
# Dep. Variable:                returns   No. Observations:                 1255
# Model:                     ARMA(0, 2)   Log Likelihood               -1571.469
# Method:                       css-mle   S.D. of innovations              0.846
# Date:                Wed, 17 Mar 2021   AIC                           3150.938
# Time:                        12:53:07   BIC                           3171.478
# Sample:                    04-09-2013   HQIC                          3158.658
#                          - 01-29-2018
# ...
#                     coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const             0.0195      0.023      0.832      0.405      -0.026       0.065
# ma.L1.returns     0.0296      0.028      1.042      0.297      -0.026       0.085
# ma.L2.returns    -0.0487      0.031     -1.568      0.117      -0.110       0.012
# ...

# %%
model_ret_ma_4 = ARMA(df.returns[1:], order=(0,4))
results_ret_ma_4 = model_ret_ma_4.fit()
print(results_ret_ma_4.summary())
print('\n')
print('LLR Test p-value = ' + str(LLR_test(model_ret_ma_3, model_ret_ma_4)))
# Out:
#                               ARMA Model Results
# ...
# Dep. Variable:                returns   No. Observations:                 1255
# Model:                     ARMA(0, 4)   Log Likelihood               -1564.769
# Method:                       css-mle   S.D. of innovations              0.842
# Date:                Wed, 17 Mar 2021   AIC                           3141.537
# Time:                        12:53:14   BIC                           3172.347
# Sample:                    04-09-2013   HQIC                          3153.117
#                          - 01-29-2018
# ...
#                     coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const             0.0196      0.022      0.889      0.374      -0.024       0.063
# ma.L1.returns     0.0239      0.028      0.851      0.395      -0.031       0.079
# ma.L2.returns    -0.0336      0.028     -1.185      0.236      -0.089       0.022
# ...

# %%
model_ret_ma_11 = ARMA(df.returns[1:], order=(0,11))
results_ret_ma_11 = model_ret_ma_11.fit()
print(results_ret_ma_11.summary())
print('\n')
print('LLR Test p-value = ' + str(LLR_test(model_ret_ma_1, model_ret_ma_11)))
# Out:
#                               ARMA Model Results
# ...
# Dep. Variable:                returns   No. Observations:                 1255
# Model:                    ARMA(0, 11)   Log Likelihood               -1559.097
# Method:                       css-mle   S.D. of innovations              0.838
# Date:                Wed, 17 Mar 2021   AIC                           3144.194
# Time:                        12:53:53   BIC                           3210.948
# Sample:                    04-09-2013   HQIC                          3169.284
#                          - 01-29-2018
# ...
#                      coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# const              0.0195      0.019      1.047      0.295      -0.017       0.056
# ma.L1.returns      0.0244      0.028      0.861      0.389      -0.031       0.080
# ...

# %% [markdown]
# ### Normalizing

# %%
#Set Benchmark
benchmark = df.returns.iloc[0]
df['norm'] = df.returns.div(benchmark).mul(100)

# %%
#ADFULLER TEST
sts.adfuller(df.norm[1:])
# Out:
# ---------------------------------------------------------------------------
# MissingDataError                          Traceback (most recent call last)
# <ipython-input-18-e7656759f7d0> in <module>
#       1 #ADFULLER TEST
# ----> 2 sts.adfuller(df.norm[1:])
#
# ~\anaconda4\lib\site-packages\statsmodels\tsa\stattools.py in adfuller(x, maxlag, regression, autolag, store, regresults)
#     307
#     308         if not regresults:
# --> 309             icbest, bestlag = _autolag(
#     310                 OLS, xdshort, fullRHS, startlag, maxlag, autolag
#     311             )
#
# ~\anaconda4\lib\site-packages\statsmodels\tsa\stattools.py in _autolag(mod, endog, exog, startlag, maxlag, method, modargs, fitargs, regresults)
#     121     method = method.lower()
#     122     for lag in range(startlag, startlag + maxlag + 1):
# --> 123         mod_instance = mod(endog, exog[:, :lag], *modargs)
#     124         results[lag] = mod_instance.fit()
#     125
#
# ...
